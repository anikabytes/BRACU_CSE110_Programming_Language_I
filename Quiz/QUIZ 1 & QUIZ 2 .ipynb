# %% [markdown]
# # QUIZ 1
#
#
# Write a Python program that asks the user for the value of n as input
# and then prints the value of y as follows.
#
# y = -3 + 5 - 7 + 9 ….. nth term
# ========================================================
# Sample Input 1:
# 1
#
# Sample Output 1:
# For n = 1, y = -3
#
# Explanation 1:
# If the user gives n = 1, it prints -3.
# ==========================
# Sample Input 2:
# 2
#
# Sample Output 2:
# For n = 2, y = 2
#
# Explanation 2:
# If the user gives n = 2, it prints 2 i.e. -3+5 = 2
# ==========================
# Sample Input 3:
# 7
#
# Sample Output 3:
# For n = 7, y = -9
#
# Explanation 3:
# If the user gives n = 7, it prints -9 i.e. -3+5-7+9-11+13-15 = -9

# %%
#quiz 1 
n=int(input('enter value of n: '))
y=-3 #at index 0, y=-3 
counter=-3 #initial counter=-3
for i in range(1,n): #(+5-7)=>(1,2)=>5 at odd index and -7 at even index 
    if(counter<0): #for -ve counter at odd index 
        counter*=-1 #converting counter to +ve 
    counter+=2#incremating counter
#     print(counter)
    if(i%2==0):
        y-=counter #if value is at even index,counter will be negative 
    else:
        y+=counter #if value is at odd index.,counter will be positive
print(y)
# Out:
# enter value of n: 3
# -5

# %% [markdown]
# # QUIZ 2
#
# Write a python program that will take a string as input from the user.  The
# input string should have a combination of BOTH the alphabets and the
# digits. Then, your task is to identify the digits from that input string
# and store those digits in a list. Finally, sort the list and print the
# sorted list and the sum of digits as output to the user.
#
# Note: You are allowed to use the built-in sort() or sorted() function here.
# ================================
# Sample Input 01:
# m4gt567q09y2
#
# Sample Output 01:
# ['0', '2', '4', '5', '6', '7', '9']
#
# 33
#
# Explanation 01:
# Here from the given input string, the digits are stored in a list. After
# sorting the digits, the sorted list is printed to the user. Then, the sum
# of the digit which is 33 is printed.
#
# ================================
# Sample Input 02:
# 954217
#
# Sample Output 02:
# There is no alphabet in the string
#
# Explanation 02:
# Here from the given input string, there is no alphabet in the string. That
# is why it is printing “There is no alphabet in the string”
# ================================
# Sample Input 03:
# abcdefgh
#
# Sample Output 03:
# There is no digit in the string
#
# Explanation 03: Here from the given input string, there is no digit in the
# string. That is why it is printing “There is no digit in the string”

# %%
#quiz 2 
input1=input('enter: ')
l1=[]#digit
l2=[]#alpha
sum=0
for i in input1:
   if i in '0123456789':
     l1.append( i)
     sum=sum+int(i)
   else:
     l2.append(i)
if len(l1)>0 and len(l2)>0:
      l=sorted(l1)
      print(l) 
      print(sum)
elif len(l1)==0:
      print('There is no digit in the string')
elif len(l2)==0:
      print('There is no alphabet in the string')
# Out:
# enter: 3
# There is no alphabet in the string

# %% [markdown]
# ### QUIZ 1
#
# Write a python program that asks the user for a range (a starting
# number(inclusive) and an ending number(inclusive)). Then take another input
# to check, if the product of all the digits of each number is divisible by
# this input or not. If it is divisible, then print it.
# ================================
# Sample Input 1:
# 25
# 30
# 4
#
# Sample Output 1:
# 12 16 0
#
# Explanation 1:
# The product of all the digits of each number from 25 to 30 is 2x5, 2x6,
# 2x7, 2x8, 2x9, 3x0. The final product is 10,12,14,16,18,0 respectively. Out
# of these numbers only 12, 16 and 0 is divisible by 4 and therefore it is
# printed.
# ================================
# Sample Input 2:
# 351
# 356
# 9
#
# Sample output 2:
# 45 90
#
# Explanation2:
# The product of all the digits of each number from 351 to 356 is 3x5x1,
# 3x5x2, 3x5x3, 3x5x4, 3x5x5, 3x5x6. The final product is 15, 30, 45, 60, 75,
# 90 respectively. Out of these numbers, only 45 and 90 are divisible by 9
# and therefore it is printed.

# %%
input1=int(input('enter a starting number: '))
input2=int(input('enter an ending number: '))
input3=int(input('enter a number: '))
list1=[]
for i in range(input1,input2+1):
    multiply=1
    string1=str(i)
    for j in string1:
        multiply*=int(j)
    list1.append(multiply)
for k in list1:
    if(int(k)%input3==0):
        print(k,end=' ')
# Out:
# enter a starting number: 351
# enter an ending number: 356
# enter a number: 9
# 45 90

# %% [markdown]
# ### QUIZ 2
# Write a python program that takes a string as an input from the user. If
# the sum of the first half of the input is equal to the sum of the last half
# of the input, then it prints “You won the lottery!”, otherwise it prints
# “You lost.”
#
# The input can be digits only (0-9). If the length of the string is even,
# then you need to consider all numbers. If the length is odd, you can ignore
# the middle number.
# [You are not allowed to use the built-in sum() and slice() for this task]
# ================================
# Sample Input 1:
# 37938725
# Sample Output 1:
# You won the lottery!
# Explanation 01:
# The first half of the input = 3+7+9+3 = 22.
# The last half of the input = 8+7+2+5 = 22.
# The summation is equal. Since the length of the string is even, we
# considered all numbers.
# ================================
# Sample Input 2:
# 7357314
# Sample Output 2:
# You lost.
# Explanation 02:
# The first half of the input = 7+3+5 = 15
# The last half of the input = 3+1+4 = 8
# The summation is not equal. Since the length of the string is odd, we
# ignored the middle number, 5

# %%
input1=input('enter a number: ')
sum1=0
sum2=0
if(len(input1)%2==0):
    for item1 in range(0,len(input1)//2 ):
        items1=int(input1[item1])
        sum1+=items1
    for item2 in range(len(input1)//2,len(input1)):
        items2=int(input1[item2])
        sum2+=items2
else:
    for item3 in range(0,len(input1)//2 - 1):
        items3=int(input1[item3])
        sum1+=items3
    for item4 in range(len(input1)//2 + 1,len(input1)-1):
        items4=int(input1[item4])
        sum2+=items4
if(sum1==sum2):
    print('You have won the lottery')
else:
    print('You lost')
# Out:
# enter a number: 37938725
# You have won the lottery

# %% [markdown]
# ### QUIZ 1
#
# Sheldon Cooper once was knocking on the door of Penny. As we all know, he
# goes like “Knock! Knock! Knock! Penny! Knock! Knock! Knock! Penny! …”. He
# continues to knock on the door until Penny opens. It requires one second
# for each word. If Penny opens the door after N(input) sec, then write a
# python program to print out the whole sentence generated by that time.
#
# Note: There will only be a single input N in your program.
# ================================
# Sample Input 1:
# 4
# Sample Output 1:
# Knock! Knock! Knock! Penny!
# Explanation1:
# In 4 sec Sheldon can only deliver 4 words. Thus the output consists of 4
# words.
# ================================
# Sample Input 2:
# 6
# Sample Output 2:
# Knock! Knock! Knock! Penny! Knock! Knock!
# Explanation2:
# In 6 sec Sheldon can only deliver 6 words. Thus the output stops after 2
# knocks on the second round.
# ================================
# Sample Input 3:
# 9
# Sample Output 3:
# Knock! Knock! Knock! Penny! Knock! Knock! Knock! Penny! Knock!
# Explanation3:
# In 9 sec Sheldon can only deliver 9 words. Thus the output stops after a
# single knock on the third round.

# %%
n=int(input('time: '))
n1='Knock!'
n2='Penny!'
n3='Knock!Knock!Knock!Penny!'
if(n==1):
    print(n1)
elif(n==2):
    print(n1*2)
elif(n==3):
    print(n1*3)
if(n==4):
    print(n3)
elif(n==5):
    print(n3+n1)
elif(n==6):
    print(n3+n1*2)
elif(n==7):
    print(n3+n1*3)
elif(n==8):
    print(n3*2)
elif(n==9):
    print()
else:
    pass
# Out:
# time: 1
# Knock!

# %% [markdown]
# ### QUIZ 2
#
# Write the python code that takes a String from the user. Then counts the
# number of vowels and the consonants present in that string and calculates
# the ratio of vowels & consonants. Finally, prints the calculated values.
# [You are not allowed to use count() function]
# ================================
# Sample Input 1:
# This is CSE110 2nd quiz
# Sample Output 1:
# No of the vowels: 5
# List of vowels:  ['i', 'e', 'u']
# No of the consonants: 10
# List of consonants:  ['t', 'h', 's', 'c', 'n', 'd', 'q', 'z']
# The ratio of vowels & consonants is  5: 10
# Explanation 01:
# In the input string, vowels have appeared 5 times and consonants have
# appeared 10 times. So, the ratio= no of vowels: no of consonants = 5:10.
#
# ================================
# Sample Input 2:
# This is List-String quiz
# Sample Output 2:
# No of the vowels: 6
# List of vowels:  ['i', 'u']
# No of the consonants: 14
# List of consonants:  ['t', 'h', 's', 'l', 'r', 'n', 'g', 'q', 'z']
# The ratio of vowels & consonants is  6: 14
# Explanation 02:
# In the input string, vowels have appeared 6 times and consonants have
# appeared 14 times. So, the ratio= no of vowels: no of consonants = 6:14.

# %%
input1=input('enter: ').replace(' ','')
input1=input1.lower()
string1='a,e,i,o,u'
string2='1,2,3,4,5,6,7,8,9,0'
string3='b,c,d,f,g,h,j,k,l,m,n,o,pq,r,s,t,v,w,x,y,z'
vowels=[]
consonants=[]
counter1=0
counter=0
for char in input1:
    if(char in string1):
        counter+=1
        if(char not in vowels):
            vowels.append(char)
    if(char  in string3) and (char not in string2):
        counter1+=1
        if(char not in consonants):
            consonants.append(char)
print('No of vowels:',counter)
print('List of  vowels:',vowels)
print('No of consonants:',counter1)
print('List of consonants:',consonants)
print('ratio of vowels and consonants',counter,':',counter1)
# Out:
# enter: This is CSE110 2nd quiz
# No of vowels: 5
# List of  vowels: ['i', 'e', 'u']
# No of consonants: 10
# List of consonants: ['t', 'h', 's', 'c', 'n', 'd', 'q', 'z']
# ratio of vowels and consonants 5 : 10

# %% [markdown]
# ### QUIZ 1
#
# Write a Python program that asks the user for quantity and takes some marks
# out of 100 as input. Valid marks are 0 to 100. However, due to user error,
# some marks may fall outside that range, say 101 or -5 (minus five). Print
# average of valid marks and percentage of invalid marks (Error Rate). Assume
# there is at least one valid mark and at least one invalid mark.
#
# ========================================================
# Sample Input 1:
# 5
# 20
# -3
# 105
# 70
# 100
#
# Sample Output 1:
# Average: 63.333333333333336
# Error Rate (%): 40.0
#
# Explanation 1:
# 5 means there are 5 inputs.
# Average of valid marks is (20+70+100)/3 =190/3  = 63.333333333333336
# -3 and 105 are invalid. So, there are 2 numbers out of 5 that are invalid.
# Hence  the percentage = 2/5x100 = 40.0
#
# ========================================================
# Sample Input 2:
# 3
# 500
# 3
# 100
#
# Sample Output 2:
# Average: 51.5
# Error Rate (%): 33.33333333333333
#
# Explanation 2:
# 3 means there are 3 inputs.
# Average of valid marks is (3+100)/2 = 103/2  = 51.5
# 500 is invalid. So, there is 1 number out of 3 that is invalid. Hence the
# percentage = 1/3x100 = 33.33333333333333

# %%
input1=int(input('how many numbers: '))
counter=0
sum=0
counter1=0
counter2=0
for i in range(0,input1):
    input2=int(input('enter numbers: '))
    counter1+=1
    if(0<=input2<=100):
        counter+=1
        sum+=input2
        average=sum/counter
    else:
        counter2+=1
    error_rate=(counter2/counter1)*100
print('average of valid marks:',average)
print('error rate:',error_rate)
# Out:
# how many numbers: 3
# enter numbers: 100
# enter numbers: 500
# enter numbers: 3
# average of valid marks: 51.5
# error rate: 33.33333333333333

# %% [markdown]
# ### Quiz 2
#
# Write a Python program that takes a list and a step size(integer number) as
# inputs from the user. Your program should swap elements from the front and
# back while maintaining the step size.
# [You are not allowed to use built-in replace() function]
# ================================
# Sample Input 1:
# A,B,C,D,E,F,G,H
# 2
# Sample Output 1:
# Before swap: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
# After swap: ['H', 'B', 'F', 'D', 'E', 'C', 'G', 'A']
# Explanation 01:
#   Here in the input, a list is given as input, and 2 is the step size.
# ‘A’(index0) swaps places with ‘H’(index -1). Then step size increments by
# 2. 0+2= 2. Swapping starts from index2. ‘C’(index2) swaps places with
# ‘F’(index -3).
# ================================
# Sample Input 2:
# A,B,C,D,E,F,G,H
# 5
# Sample Output 2:
# Step size is not suitable
# Explanation 02:
#   Here in the input, a list is given as input, and 5 is the step size which
# is greater than half of the list length. So swapping is not possible.
# ================================
# Sample Input 3:
# A,B,C,D,E,F,G,H,I,J,K
# 3
# Sample Output3:
# Before swap: ['A','B', 'C',  'D', 'E', 'F', 'G','H',  'I', 'J','K']
# After swap:    ['K', 'B', 'C', 'H', 'E', 'F', 'G', 'D', 'I', 'J', 'A']
# Explanation 03:
#   Here in the input, a list is given as input, and 3 is the step size.
# ‘A’(index0) swaps places with ‘K’(index -1). Then step size increments by
# 3. 0+3= 3. Swapping starts from index3. ‘D’(index3) swaps places with
# ‘H’(index -4).

# %%
input1=input('enter: ').split(',')
list1=[]
input2=int(input('enter:'))
index=0
for item in range(0,len(input1)//2,input2):
    item1=input1[item]
    input1[item]=input1[-index-1]
    input1[-index-1]=item1
    index+=input2
print(input1)
# Out:
# enter: A,B,C,D,E,F,G,H
# enter:2
# ['H', 'B', 'F', 'D', 'E', 'C', 'G', 'A']
